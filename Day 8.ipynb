# %% [markdown]
# # Chapter 3 Indexing

# %%
import pandas as pd
football_data = pd.read_csv('Euro_2012_stats_TEAM.csv')

# %%
football_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ## 3.1 Display first 5 observations of first 5 features

# %%
#iloc - integer location

# %%
football_data.iloc[0:5,0:5]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%

# %%
football_data.iloc[2:12,3:9]
# Out:
#     Shots off target Shooting Accuracy % Goals-to-shots  \
# 2                 10             50.0%            20.0%
# 3                 18             50.0%            17.2%
# 4                 24             37.9%             6.5%
# 5                 32             47.8%            15.6%
# 6                 18             30.7%            19.2%
# 7                 45             43.0%             7.5%
# 8                 36             25.0%             4.1%
# 9                 23             39.4%             5.2%
# 10                42             34.3%             9.3%
# 11                12             36.8%             5.2%
#
#     Total shots (inc. Blocked)  Hit Woodwork  Penalty goals
# 2                           27             1              0
# 3                           40             0              0
# 4                           65             1              0
# 5                           80             2              1
# ...

# %%
football_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_data.iloc[[1,5,11],[4,31,0,1]]
# Out:
#    Shooting Accuracy  Red Cards                 Team  Goals
# 1              41.9%          0       Czech Republic      4
# 5              47.8%          0              Germany     10
# 11             36.8%          1  Republic of Ireland      1

# %%
football_data.loc[[1,5,11],["Team","Goals"]]
# Out:
#                    Team  Goals
# 1        Czech Republic      4
# 5               Germany     10
# 11  Republic of Ireland      1

# %% [markdown]
# ## Chapter 4 Delete and drop

# %%
football_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
del football_data['Hit Woodwork']

# %%
football_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_data.drop(labels=['Penalties not scored','Saves made'],axis=1)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_data.drop(labels=['Penalties not scored','Saves made'],axis=1, inplace=True)

# %% [markdown]
# ## Chapter 5 Series and DataFrame

# %%
import pandas as pd

# %%
yogesh_marks=[50,45,63,85]

# %%
type(yogesh_marks)
# Out:
# list

# %%
pd.Series(data=yogesh_marks)
# Out:
# 0    50
# 1    45
# 2    63
# 3    85
# dtype: int64

# %%
bike={'model':['rx100','rs 200'],
     'number':['5658','5566']}

# %%
bike
# Out:
# {'model': ['rx100', 'rs 200'], 'number': ['5658', '5566']}

# %%
type(bike)
# Out:
# dict

# %%
pd.DataFrame(data=bike)
# Out:
#     model number
# 0   rx100   5658
# 1  rs 200   5566

# %% [markdown]
# ## Chapter 6 - Apply Function

# %%
pd.read_csv('student-mat.csv')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
import pandas as pd
student_data=pd.read_csv('student-mat.csv')

# %%
student_data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
import pandas as pd
student_data=pd.read_csv('student-mat.csv')
student_data['Mjob'].str.capitalize()
# Out:
# 0       At_home
# 1       At_home
# 2       At_home
# 3        Health
# 4         Other
#          ...
# 390    Services
# 391    Services
# 392       Other
# 393    Services
# 394       Other
# Name: Mjob, Length: 395, dtype: object

# %%
student_data["Fjob"].str.upper()
# Out:
# 0       TEACHER
# 1         OTHER
# 2         OTHER
# 3      SERVICES
# 4         OTHER
#          ...
# 390    SERVICES
# 391    SERVICES
# 392       OTHER
# 393       OTHER
# 394     AT_HOME
# Name: Fjob, Length: 395, dtype: object

# %%
def get_age (x):
    if x>17:
        return 1
    else:
        return 0
get_age(18)
# Out:
# 1

# %%
student_data["Eligibility_criteria"]=student_data["age"].apply(lambda x: 1 if x > 17 else 0)

# %%
student_data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
student_data["Eligibility_criteria"]=student_data["age"].apply(get_age)

# %%
student_data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
student_data["sex_num"]=student_data["sex"].str.apply(lambda x: 1 if x=='F' else 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 student_data["sex_num"]=student_data["sex"].str.apply(lambda x: 1 if x=='F' else 0)
#
# AttributeError: 'StringMethods' object has no attribute 'apply'

# %%
def sex_num (x):
    if x=='F':
        return 1 

    else:
        return 0
        
sex_num('M')
# Out:
# 0

# %%
student_data["sex_num"]=student_data["sex"].apply(sex_num)

# %%
student_data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
**Creating Github account and upload your assignemnt.**
**TASK  - Explore Query Function.-** https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html 
**Lamba function along with filter and map**

# %%
mail id - gurureddyg.uk@gmail.com
# Out:
#   Cell In[46], line 1
#     mail id - gurureddyg.uk@gmail.com
#          ^
# SyntaxError: invalid syntax

# %%
https://forms.gle/zKJXyxxb53b3Qund7

# %%
Daily- evaluation form- https://forms.gle/zKJXyxxb53b3Qund7
